# %% [markdown]
# ## Q1
#
# Write a program to display the fibonacci sequences up to $n^\text{th}$ term where $n$ is provided by the user.
#
# *__Answer__*
#
#
# ## Q2
#
#  Write a program to repeatedly check for the largest number until the user enters ''done''.
#
# *__Answer__*
#
#
# ## Q3
#
#  Write a program to find the sum of all Odd and Even numbers up to a number specified by the user.
#
# *__Answer__*
#
#
# ## Q4
#
#  Explain the need for \verb"continue" and \verb"break" statements. Write a program to check whether a number is prime or not. Prompt the user for input.
#
# *__Answer__*
#
#
# ## Q5
#
#  Write a program using functions to find the value of $^nP_r$ and $^nC_r$ without using inbuilt \verb"factorial()" function.
#
# *__Answer__*
#
#
# ## Q6
#
#  Write a program to print the sum of the following series $\ds 1 + \frac{1}{2} +\cdots + \frac{1}{n}$
#
# *__Answer__*
#
#
# ## Q7
#
#  What is the difference between list and tuples in Python?
#
# *__Answer__*
#
#
# ## Q8
#
#  How does break, continue and pass work?
#
# *__Answer__*
#
#
# ## Q9
#
#  What is a dictionary in Python?
#
# *__Answer__*
#
#
# ## Q10
#
#  Discuss the following list functions: a) \verb"len()" b) \verb"sum()" c) \verb"any()" d) \verb"all()" e) \verb"sorted()"
#
# *__Answer__*
#
#
# ## Q11
#
#  Explain the following list methods with an example. a) \verb"append()" b)\verb"extend()" c) \verb"insert()" d) \verb"index()" e) \verb"sort()"
#
# *__Answer__*
#
#
# ## Q12
#
#  Write Python program to check if the items in the list are sorted in ascending or descending order and print suitable messages accordingly. Otherwise, print ``Items in list are not sorted''
#
# *__Answer__*
#
#
# ## Q13
#
#  Write Python program to sort words in a sentence in decreasing order of their length. Display the sorted words along with their length.
#
# *__Answer__*
#
#
# ## Q14
#
#  Write a function which receives a variable number of strings as arguments. Find unique characters in each string.
#
# *__Answer__*
#
#
# ## Q15
#
#  Write Pythonic code to create a function called most\_frequent that takes a string and prints the letters in decreasing order of frequency. Use dictionaries.
#
# *__Answer__*
#
#
# ## Q16
#
#  Illustrate the different types of control flow statements available in Python with flowcharts.
#
# *__Answer__*
#
#
# ## Q17
#
#  Explain the following:\begin{enumerate} \item List Slicing and List Mutability. \item List Accessing Methods and List Comprehension. \end{enumerate}
#
# *__Answer__*
#
#
# ## Q18
#
#  Explain Selection and Insertion sort methods with python program.
#
# *__Answer__*
#
#
# ## Q19
#
#  Explain Merge and Quick sort methods with python program.
#
# *__Answer__*
#
#
# ## Q20
#
#  Explain Dictionary Operation and Methods.
#
# *__Answer__*
#
#
# ## Q21
#
#  Write code snippets in Python to perform the following: Accessing, Modifying and Deleting Elements of a Tuple
#
# *__Answer__*
#
#
# ## Q22
#
#  What are the conditional statements used in python?
#
# *__Answer__*
#
#
# ## Q23
#
#  Define if $\cdots$ else statements in python.
#
# *__Answer__*
#
#
# ## Q24
#
#  Define chained conditionals.
#
# *__Answer__*
#
#
# ## Q25
#
#  What are the different iterative statements?
#
# *__Answer__*
#
#
# ## Q26
#
#  Define range() function and its syntax.
#
# *__Answer__*
#
#
# ## Q27
#
#  Define while loop.
#
# *__Answer__*
#
#
# ## Q28
#
#  Write the syntax for nested for loops and nested while loop statements.
#
# *__Answer__*
#
#
# ## Q29
#
#  What is python break statement?
#
# *__Answer__*
#
#
# ## Q30
#
#  What is python continue statement.
#
# *__Answer__*
#
#
# ## Q31
#
#  Explain in detail about Control flow structures.
#
# *__Answer__*
#
#
# ## Q32
#
#  Write a program using while loop first N numbers divisible by 5.
#
# *__Answer__*
#
#
# ## Q33
#
#  List some of the methods in List Operations.
#
# *__Answer__*
#
#
# ## Q34
#
#  List out the types of Modules and Explain any two types in detail.
#
# *__Answer__*
#
#
# ## Q35
#
#  Write Python program to replace comma-separated words with hyphens and print hyphen-separated words in ascending order.
#
# *__Answer__*
#
#
# ## Q36
#
#  Write Pythonic code to multiply two matrices using nested loops and also perform transpose of the resultant matrix using class.
#
# *__Answer__*
#
#
# ## Q37
#
#  Program to demonstrate the Overriding of the Base Class method in the Derived Class.
#
# *__Answer__*
#
#
# ## Q38
#
#  Write Python program to demonstrate Multiple Inheritance.
#
# *__Answer__*
#
#
# ## Q39
#
#  What are the different function prototypes? Explain it with suitable example.
#
# *__Answer__*
#
#
# ## Q40
#
#  Write a program to circulate value of $N$ numbers.
#
# *__Answer__*
#
#
# ## Q41
#
#  Write a program to compute the factorial of a given number using recursion.
#
# *__Answer__*
#
#
# ## Q42
#
#  Discuss Function arguments in Python.
#
# *__Answer__*
#
#
# ## Q43
#
#  What are the types of parameters in functions?
#
# *__Answer__*
#
#
# ## Q44
#
#  What are the various parameter passing techniques?
#
# *__Answer__*
#
#
# ## Q45
#
#  What is recursive function and its limitations?
#
# *__Answer__*
#
#
# ## Q46
#
#  Write the merits of using functions in a program.
#
# *__Answer__*
#
#
# ## Q47
#
#  Write a function called \verb"describe_city()" that accepts the name of a city and its country. The function should print a sentence, like "Mumbai is in India". Give the parameter for the country a default value. Call your function for three different cities, at least a of which is not in the default country.
#
# *__Answer__*
#
#
# ## Q48
#
#  Write a function that accepts a list of items a person wants on a sandwich. The function should have a parameter that collects as many items as the function call provides, and it should print a summary of the sandwich that is being ordered. Call the function three times, using a different number of arguments each time.
#
# *__Answer__*
#
#
# ## Q49
#
#  Write a function that stores information about a car in a dictionary. The function should always receive a manufacturer and a model name. It should then accept an arbitrary number of keyword arguments. Call the function with two optional features like color and tow package.\\ \verb"make_car(`subaru',`outback',color=`blue',tow_package=True)"\\
#
# *__Answer__*
#
#
# ## Q50
#
#  Write Pythonic code to solve the quadratic equation $ax^2 + bx + c = 0$ by getting input for coefficients from the user.
#
# *__Answer__*
#
#
# ## Q51
#
#  Find the area and perimeter of a circle using functions. Prompt the user for input.
#
# *__Answer__*
#
#
# ## Q52
#
#  Discuss the following methods supported by compiled regular expression objects: a) "search()" b) "match()" c) "findall()"
#
# *__Answer__*
#
#
# ## Q53
#
#  Given the Coordinates(x,y) of a center of a Circle and its radius, write Python program to determine whether the Point lies inside the Circle, on the Circle or outside the Circle.
#
# *__Answer__*
#
#
# ## Q54
#
#  Write Pythonic code to create a function named "move_rectangle()" that takes an object of Rectangle class and two numbers named dx and dy. It should change the location of the Rectangle by adding dx to the x coordinate of corner and adding dy to the y coordinate of corner.
#
# *__Answer__*
#
#
# ## Q55
#
#  How will you create a Package and import it? Explain it with an example program.
#
# *__Answer__*
#
#
# ## Q56
#
#  Explain the concept of Exception Handling in Python with suitable program.
#
# *__Answer__*
#
#
# ## Q57
#
#  List the different ways to read a file. What the difference is between append and write mode?
#
# *__Answer__*
#
#
# ## Q58
#
#  Write Python Program to Reverse Each Word in ``secret_societies.txt'' file.
#
# *__Answer__*
#
#
# ## Q59
#
#  Write Python Program to Count the Occurrences of Each Word and Also Count the Number of Words in a ``quotes.txt'' File.
#
# *__Answer__*
#
#
# ## Q60
#
#  Write a program to count the number of words in a text file.
#
# *__Answer__*
#
#
# ## Q61
#
#  Consider a File Called ``workfile''. Write Python Program to Read and Print Each Byte in the Binary File.
#
# *__Answer__*
#
#
# ## Q62
#
#  Write few NumPy package commands useful for linear algebra with examples.
#
# *__Answer__*
#
#
# ## Q63
#
#  Explain different ways to create an empty NumPy array in Python.
#
# *__Answer__*
#
#
# ## Q64
#
#  Write few SciPy package commands useful for statistical tests with examples.
#
# *__Answer__*
#
#
# ## Q65
#
#  Write few SciPy package commands useful for statistical distribution with examples.
#
# *__Answer__*
#
#
# ## Q66
#
#  What is tkinter?
#
# *__Answer__*
#
#
# ## Q67
#
#  Write the difference between Python Modules and Packages.
#
# *__Answer__*
#
#
# ## Q68
#
#  Write a python code for the developing graphical user interface for calculation sum of two given numbers.
#
# *__Answer__*
#
#
# ## Q69
#
#  Write a Python GUI program to create a window and disable to resize the window using tkinter module.
#
# *__Answer__*
#
#
# ## Q70
#
#  Write a Python GUI program to create three radio buttons widgets using tkinter module.
#
# *__Answer__*
#
#
# ## Q71
#
#  Write the syntax for composition.
#
# *__Answer__*
#
#
# ## Q72
#
#  State the differences between linear search and Binary search.
#
# *__Answer__*
#
#
# ## Q73
#
#  You work for a manufacturer, and have been asked to calculate the total profit made on the sales of a product. You are given a dictionary containing the cost price per unit (in dollars), sell price per unit (in dollars), and the starting inventory. Return the total profit made, rounded to the nearest dollar. Assume all of the inventory has been sold.
#
# *__Answer__*
#
#
# ## Q74
#
#  Create a function that takes two numbers as arguments (num, length) and returns a list of multiples of num up to length.
#
# *__Answer__*
#
#
# ## Q75
#
#  Given two lines, write a Python function to determine whether or not they are parallel. Lines are represented by a list [a, b, c], which corresponds to the line ax+by=c.
#
# *__Answer__*
#
#
# ## Q76
#
#  Create methods for the Calculator class that can do the following: Add, Subtract, Multiply and Divide two numbers.
#
# *__Answer__*
#
#
# ## Q77
#
#  Create a function that takes a list and returns a new list containing only prime numbers.
#
# *__Answer__*
#
#
# ## Q78
#
#  Create a function that takes numbers as arguments, adds them together, and returns the product of digits until the answer is only 1 digit long.
#
# *__Answer__*
#
#
# ## Q79
#
#  Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included).
#
# *__Answer__*
#
#
# ## Q80
#
#  Define a function which can generate a dictionary where the keys are numbers between 1 and 20 (both included) and the values are square of keys. The function should just print the values only.
#
# *__Answer__*
#
#
# ## Q81
#
#  Define a class Person and its two child classes: Male and Female. All classes have a method "getGender" which can print "Male" for Male class and "Female" for Female class.
#
# *__Answer__*
#
#
# ## Q82
#
#  Write a Python class to convert an integer to a roman numeral.
#
# *__Answer__*
#
#
# ## Q83
#
#  Write a Python class named Rectangle constructed by a length and width and a method which will compute the area of a rectangle.
#
# *__Answer__*
#
#
# ## Q84
#
#  Write a python code for the developing graphical user interface for adding, subtracting, dividing and multiplying two given numbers.
#
# *__Answer__*
#
#
# ## Q85
#
#  How to add a border (filled with 0's) around an existing two dimensional array?
#
# *__Answer__*
#
#
# ## Q86
#
#  Create a function that takes an integer and outputs an $n \times n$ square solely consisting of the integer $n$.
#
# *__Answer__*
#
#
# ## Q87
#
#  How to add a row at top in pandas DataFrame? What is Forward and backward filing of mising values of DataFrame columns in Pandas?
#
# *__Answer__*
#
#
# ## Q88
#
#  What Advantages Do Numpy Arrays Offer Over (nested) Python Lists?
#
# *__Answer__*
#
#
# ## Q89
#
#  Explain all file processing modes supported in Python.
#
# *__Answer__*
#
#
# ## Q90
#
#  Write few NumPy package commands useful for linear algebra with examples.
#
# *__Answer__*
#
#
# ## Q91
#
#  Explain different ways to create an empty NumPy array in Python.
#
# *__Answer__*
#
#
# ## Q92
#
#  Write few SciPy package commands useful for statistical parametric and nonparametric tests with proper syntax.
#
# *__Answer__*

# %%
class rect(self,x,y)
        
    def move_rect(dx,dy):
        self.x=self.x+dx
        self.y=self.y+dy
        return (self.x,self.y)
