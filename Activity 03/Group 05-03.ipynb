# %% [markdown]
# # Simple Linear Regression (Scipy)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# %%
# Importing the dataset
dataset = pd.read_csv('Salary_Data.csv')
print(dataset.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
model = ols("Salary ~ YearsExperience",dataset).fit()

# Print the summary
print(model.summary())
print("\n model.pvalues:\n",model.pvalues,"\n\n")
# Peform analysis of variance on fitted linear model
anova_results = anova_lm(model)

print('\nANOVA results')
anova_results
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Sat, 10 Jul 2021   Prob (F-statistic):           1.14e-20
# Time:                        16:33:07   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        2.579e+04   2273.053     11.347      0.000    2.11e+04    3.04e+04
# YearsExperience  9449.9623    378.755     24.950      0.000    8674.119    1.02e+04
# ==============================================================================
# Omnibus:                        2.140   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                1.569
# Skew:                           0.363   Prob(JB):                        0.456
# Kurtosis:                       2.147   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  model.pvalues:
#  Intercept          5.511950e-12
# YearsExperience    1.143068e-20
# dtype: float64
#
#
#
# ANOVA results
#                    df        sum_sq       mean_sq           F        PR(>F)
# YearsExperience   1.0  2.085685e+10  2.085685e+10  622.507203  1.143068e-20
# Residual         28.0  9.381286e+08  3.350459e+07         NaN           NaN

# %%
# Retrieve the parameter estimates
offset, coef = model._results.params
plt.scatter(dataset.YearsExperience,dataset.Salary,color="r")
plt.plot(dataset.YearsExperience, dataset.YearsExperience*coef + offset,color="b")
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Simple Linear Regression')
plt.show()

# %%
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
regr = linear_model.LinearRegression()
regr.fit(pd.DataFrame(dataset.YearsExperience),dataset.Salary)
regr.predict(pd.DataFrame(dataset.YearsExperience))
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [9449.96232146]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3d983a8e49bf> in <module>
#       6 # The mean squared error
#       7 print('Mean squared error: %.2f'
# ----> 8       % mean_squared_error(diabetes_y_test, diabetes_y_pred))
#       9 # The coefficient of determination: 1 is perfect prediction
#      10 print('Coefficient of determination: %.2f'
#
# NameError: name 'diabetes_y_test' is not defined

# %%
regr.coef_
